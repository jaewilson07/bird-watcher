# %% [markdown]
# # Step 1: Setup
#
# ![Step 1 diagram](https://raw.githubusercontent.com/jaewilson07/bird-watcher/main/docs/diagrams/01-step.png)
#
# ## What you're building today
#
# A project skeleton. No fancy bird detection yet — just the folders and a tiny Python program that proves everything is wired up.
#
# By the end of this notebook you should be able to run `python -m bird_watcher` and see a version number.
#
# ## How to use this notebook
#
# 1. Click the **Open in Colab** badge above (or just run this in Jupyter if you have it)
# 2. Run each cell one at a time
# 3. Read the explanation before running the code
# 4. When the output looks right, you've finished this issue
#
# Each cell is small on purpose. One concept per cell. If something confuses you, re-read the text above the code.

# %% [markdown]
# ## Step 1.1 — Check your Python
#
# Let's see what version of Python is running. We need 3.10 or newer.

# %%
import sys
print("Python version:", sys.version)
assert sys.version_info >= (3, 10), "Need Python 3.10 or newer"
print("OK")
# Out:
# Python version: 3.11.15 (main, Jun  2 2026, 22:26:03) [Clang 22.1.3 ]
# OK

# %% [markdown]
# ## Step 1.2 — Hello bird watcher
#
# Now let's import the package and print its version. This proves the skeleton is wired up correctly.

# %%
import bird_watcher
print("bird-watcher version:", bird_watcher.__version__)
# Out:
# bird-watcher version: 0.0.0

# %% [markdown]
# ## Done?
#
# If you see something like:
#
# ```
# bird-watcher version: 0.0.0
# ```
#
# then the skeleton works. Close this issue and move on to **#2: View the stream**.
#
# ---
#
# **Coming up next**: We open the camera stream from your old phone and save one snapshot to disk. First time the bird watcher sees anything. 🐦
